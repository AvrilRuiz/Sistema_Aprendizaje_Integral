# %% [markdown]
# <a href="https://colab.research.google.com/github/AvrilRuiz/Sistema_Aprendizaje_Integral/blob/main/A00833018_Entrega3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Entrega 3 del Proyecto Integrador**

# %% [markdown]
# ### Avril Michelle Ruiz Martínez
#
# ### A00833018
#
# ### Pensamiento computacional para ingeniería
#
# ### Profesor: Ing. Germán Domínguez
#
# ### 17/10/21
#
# https://colab.research.google.com/drive/1yUn81L8bdRMEFvBZvbDgLUS0AwBFgtqT?usp=sharing

# %% [markdown]
# https://github.com/AvrilRuiz/Sistema_Aprendizaje_Integral

# %% [markdown]
# **Describir la problemática a resolver, cómo se planea solucionar y la funcionalidad del programa que dará solución al problema.**
# ---
#
#
#
#
#  La prueba PISA, por sus siglas en inglés, es un examen que permite evaluar el sistema educativo de un país o región, para encontrar áreas de oportunidad en éste. Más de 80 países participan en esta prueba y la aplican cada 3 años entre alumnos de 15 y 16 años. En el 2018 la prueba indicó que alrededor de la mitad de los estudiantes mexicanos aprendieron lo suficiente en lectura, ciencias y matemáticas. Lo anterior significa que existe una alarmante cantidad de alumnos en México que no han adquirido los conocimientos necesarios para continuar su vida estudiantil. Por esta razón, la problemática consiste en desarrollar un sistema de aprendizaje integral que le permita a los alumnos que van a presentar su prueba PISA mejorar en las áreas de lectura, matemáticas y ciencias.
#
#
# Para solucionar dicha problemática se utilizan 8 funciones principales que le permitirán al usuario estudiar para las diferentes áreas de este examen:
#
# La función menu despliega el menú de opciones con múltiples print, y  regresa, con un return la opción que se le preguntó al usuario con input.
#
# La función registrar pregunta permite al usuario registrar una pregunta a la base datos, así como el enfoque y las posibles respuestas, por medio de varios input.
#
# Las funciones de actualizar pregunta, estudiar área, presentar quiz, reportar calificaciones y salir, únicamente muestran el nombre de la función, con print,  si el usuario las elige.
#
# En la función main se utiliza un ciclo while que llama a la función menu, y a la que que el usuario eligió en la función menu mediante varios if, mientras esta opción no sea la 6 (salir). Si se escoge un número que no está dentro del rango 1 a 6, se imprime que la opción es incorrecta, y vuelve a ejecutarse la función menu, hasta que se seleccione el 6 y se salga del ciclo while, para finalizar se llama a la función salir y se termina el programa.
#
# Para el usuario, lo primero que aparece es el menú de opciones y enseguida se le pide que elija una opción. Si escoge la opción 1 se ejecuta la función registrar pregunta, por lo que debe registrar el área de enfoque, la pregunta y las posibles respuestas. Si elige alguna opción del 2 al 5, se manda llamar a la opción correspondiente, que únicamente muestran el nombre de la función que se mandó llamar. Si el usuario elige un número menor a 1 o mayor a 6 en la pantalla le aparecerá un mensaje de error. Mientras el usuario no escoja la opción 6 para salir, se seguirá desplegando el menú y deberá seleccionar alguna opción. Sin embargo, si se selecciona la opción 6, se sale del ciclo while y únicamente se desplegará el nombre de esta función y se dará por finalizado el programa.

# %% [markdown]
# ## Algoritmos y pruebas
#
# Antes de cualquier cosa, declaré las listas vacías: preguntas, ids_mate, ids_lectura, id_ciencias, preguntas_quiz y calificaciones.
# También tuve que crear la lista enfoques, que contenía los enfoques posibles y una variable contador_usuario que le di un valor de cero.
#
#
# ## Función registrar_pregunta
# ###ALGORITMO
# 1.	Se crea una lista vacía llamada pregunta.
# 2.	Se pregunta por el enfoque.
# 3.	Se pregunta  por la redacción de la pregunta.
# 4.	Se pregunta por las 4 posibles respuestas (con un for).
# 5.  Se pregunta por la respuesta correcta.
# 6.	En el caso del ID, en vez de preguntarlo, decidí asignarlo, para esto, use la longitud de preguntas y le sumé 1; así cada vez que se le agregue una pregunta a preguntas y la longitud de preguntas aumente, también lo hará el ID.
# 7.	En la lista pregunta se guardan los datos con append.
# 8.	Cuando ya estén todos los datos en la lista pregunta, se agrega la lista pregunta a la lista preguntas con append.
#
#
# ###CASO 1
#
# Datos de entrada:
#
# >> 2
#
# >> ¿Cuánto es 2+3?
#
# >> 4
#
# >> 5
#
# >> 6
#
# >> 7
#
# >> 5
#
# Resultado esperado:
#
# preguntas = [[1, 2, '¿Cuánto es 2+2?', '3', '4', '5', '6', '4']]
#
#
# ###CASO 2
#
# Datos de entrada:
#
# >> 1
#
# >> ¿Quién escribió Romeo y Julieta?
#
# >> Cervantes
#
# >> Austen
#
# >> Shakespeare
#
# >> Gray
#
# >> Shakespeare
#
#
# Resultado esperado:
#
# preguntas = [[2, 1, '¿Cuánto es 2+2?', '3', '4', '5', '6', '4'], [2, 1, ¿Quién escribió Romeo y Julieta?','Cervantes', 'Austen', 'Shakespeare', 'Gray', 'Shakespeare']]

# %% [markdown]
# ##Función actualizar_pregunta
# ###ALGORITMO
# 1.	Primero declaro una variable booleana con un False.
# 2.	Con un for se recorre pregunta por pregunta y se imprimen todos los datos que contenga cada una.
# 3.	Se le pregunta al usuario el ID de la pregunta que desea cambiar.
# 4.	Con otro for se valida si existe una pregunta con ese ID.
# 5.	Si el ID de la pregunta a cambiar es el mismo que el de una pregunta en preguntas, entonces la variable booleana es igual a True.
# 6.	En este caso se imprime esa pregunta y sus datos.
# 7.	Se pregunta al usuario todos los datos a cambiar.
# 8.	Se le pregunta al usuario si se está seguro de actualizar los cambios.
# 9.	Si el usuario dice que sí está seguro, entonces se actualizan los datos en los que hubiese ingresado algo, si solo le daba enter, no se cambiaba nada.
# 10.	Si no hubiese existido ese ID, entonces la variable booleana seguiría siendo False y en este caso, se le indica al usuario que no existe ese ID.
#
# ###CASO 1
#
# Datos de entrada:
#
# >> 1
#
# >> 2
#
# >> 5 + 5
#
# >> 4
#
# >> 7
#
# >> 10
#
# >> 10
#
# >> no
#
#
# Resultado esperado:
#
# -No se cambia nada-
#
#
# ###CASO 2
#
# Datos de entrada:
#
#
# >> 1
#
# >> 2
#
# >> 5 +5
#
# >> 4
#
# >> 6
#
# >> 7
#
# >> 10
#
# >> 10
#
# >> sí
#
#
# Resultado esperado:
#
# preguntas = [[1, 2, ‘5+5’, ‘4’, ’6’, ‘7’, ’10’, ‘10’]]

# %% [markdown]
# ## Función estudiar_area
# ###ALGORITMO
# 1.	Se manda llamar a otra función llamada organizar_preguntas.
# 2.	En organizar_preguntas se recorren todas las preguntas con un for y se van agregando los IDs con append a las listas de ids_mate, ids_lectura, ids_ciencias, según el enfoque de cada una, validando que no haya algún ID repetido.
# 3.	Después, cree una lista vacía llamada preguntas_estudiar.
# 4.	Se pregunta al usuario el enfoque que se desea estudiar.
# 5.	Dependiendo del enfoque que se haya elegido se imprime un mensaje con la cantidad de preguntas disponibles de dicho enfoque.
# 6.	Se pregunta también la cantidad de preguntas a estudiar.
# 7.	Con esta información se valida si hay suficientes preguntas para estudiar el área seleccionada.
# 8.	Si son suficientes, entonces se agrega la cantidad de preguntas deseada a preguntas_estudiar, de la lista de IDs correspondiente al enfoque que se haya escogido (esto con un for en un rango de la cantidad de preguntas deseadas).
# 9.	Se imprimen las preguntas en preguntas_estudiar (la cantidad que el usuario haya indicado), con ayuda de una asignación de variables, elemento por elemento
# 10.	 Si no hay suficientes preguntas, se le imprime este mensaje al usuario.
#
# ###CASO 1
#
# Datos de entrada:
#
# >> 2
#
# >> 3
#
#
# Resultado esperado:
#
# Pregunta: ¿Cuánto es 3 + 5?
#
# a)10
#            b)7
#                   c)8
#                      d)9
#
# Correcta: 8
#
#
# Pregunta: ¿Cuánto es 45 + 5?
#
# a)50
#     b)3
#          c)46
#                d)34
#
# Correcta: 50
#
#
# Pregunta: ¿Cuánto es 67 - 45?
#
# a)22
#       b)25
#              c)12
#                     d)18
#
# Correcta: 22
#
#
#
# ###CASO 2
#
#
# Datos de entrada:
#
# >> 2
#
# >> 5
#
#
# Resultado esperado:
#
# No hay suficientes preguntas de esta área.

# %% [markdown]
# ## Función presentar_quiz
# ###ALGORITMO
# 1.	Primero llamo a la variable global contador_usuario, para poder usarla en esta función.
# 2.	Asimismo uso el método clear para limpiar las preguntas_quiz, y así no aumenten cada vez que corra el programa.
# 3.	Mando llamar a la función organizar_preguntas, ya que serán necesarias las listas con los IDs.
# 4.	Declaro una variable booleana para cada enfoque con un valor False.
# 5.	Se valida que hayan más de 10 o 10 preguntas, y que mínimo haya una de cada enfoque.
# 6.	Si se cumplen dichas condiciones, entonces relleno las 8 primeras posiciones de mi lista preguntas_quiz con las primeras 8 preguntas en preguntas, esto con un for.
# 7.	Se realiza una asignación de variables a la lista.
# 8.	Con if voy preguntando si existe alguna pregunta de cada enfoque.
# 9.	Si es así, su variable booleana correspondiente se vuelve True.
# 10.	Después, voy rellenando las dos preguntas faltantes según sea el caso, para esto cree las funciones: completar_1_2_3, completar_1_2, completar_1_3, completar_2_3, completar_1, completar_2 y completar_3. Los números de cada función son los posibles enfoques que se encuentran en preguntas_quiz, y así nos aseguramos de que dentro de las 10 preguntas haya al menos una de cada área.
# 11.	Cuando ya se tiene la lista preguntas_quiz, entonces se declaran las variables contador_correctas y contador_incorrectas con cero.
# 12.	Importo time e imprimo un mensaje al usuario con el tiempo que cuenta para realizar su quiz.
# 13. Declaro la variable start con el tiempo antes de iniciar el quiz.
# 14.	Con un for se despliegan las preguntas y las opciones de las 10 preguntas del quiz y dentro del mismo for:
# 15.	Se pregunta al usuario su respectiva respuesta.
# 16.	Declaro una variable finish que toma el tiempo en que el usuario introduce su respuesta.
# 17.	Calculo el tiempo que le tomó al usuario contestar y se lo resto a los 20 minutos.
# 18.	Se despliega al usuario un mensaje con el tiempo restante.
# 19.	 Si la respuesta del usuario es la misma a la correcta, entonces a contador_correctas  se le suma 1.
# 20.	Si es diferentes, es decir, si su respuesta es diferente a la correcta, entonces a contador_incorrectas se le suma 1.
# 21.	Por último, se le aumenta 1 al contador_usuario, que es para conocer el total de usuarios, y a la lista calificaciones se le agrega el valor final de contador_correctas:
#
#
# ###CASO 1
#
# Datos de entrada:
#
# Menos de 10 datos de preguntas o no hay al menos una pregunta de cada enfoque.
#
# Resultado esperado:
#
# No hay suficientes preguntas, no se puede presentar el quiz.
#
#
# ###CASO 2
#
# Datos de entrada:
#
# -Sí hay suficientes preguntas-
#
# Respuesta1
#
# Respuesta2
#
# Respuesta3
#
# Respuesta4
#
# Respuesta5
#
# Respuesta6
#
# Respuesta7
#
# Respuesta8
#
# Respuesta9
#
# Respuesta10
#
# Resultado esperado:
#
# Si todas sus respuestas son correctas, a la lista calificaiones se agrega un 10.

# %% [markdown]
# ## Función reportar_calificaciones
# ###ALGORITMO
# 1.	Primero valido si ya hay calificaciones, luego se define a la variable promedio como la sumatoria de calificaciones (mediante la función sum), por 10 y dividida entre la cantidad de calificaciones en la lista calificaciones (con len).
# 2.	Luego, a total_preguntas se le da el valor de contador_usuario multiplicado por 10, esto porque cada usuario contesta un total de 10 preguntas.
# 3.	La variable total_preguntas_correctas es la sumatoria de las calificaciones (otra vez se obtiene con sum).
# 4.	Así, porcentaje_correctas es igual a total_preguntas_correctas, multiplicado por 100, y dividido entre total_preguntas; aquí se usa una regla de 3 para obtener el porcentaje.
# 5.	Para encontrar porcentaje_incorrectas únicamente se le resta el porcentaje_correctas a 100.
# 6.	Para finalizar, se despliega el total de usuarios, el promedio de las calificaciones, el porcentaje de preguntas correctas y el porcentaje de preguntas incorrectas.
#
# ###CASO 1
#
# Datos de entrada:
#
# contador_usuarios = 4
#
# calificaciones = [10, 5, 8, 7]
#
# Resultado esperado:
#
# Total de usuarios:      4
#
# Promedio:               75.0
#
# Porcentaje correctas:   75.0%
#
# Porcentaje incorrectas: 25.0%
#
#
# ###CASO 2
#
# Datos de entrada:
#
#
# contador_usuarios = 3
#
# calificaciones = [9, 6, 6]
#
# Resultado esperado:
#
# Total de usuarios:      3
#
# Promedio:               70.0
#
# Porcentaje correctas:   70.0%
#
# Porcentaje incorrectas: 30.0%

# %% [markdown]
# ## **REFLEXIÓN**
#
# Durante el desarrollo de este proyecto pude poner en práctica y tuve la oportunidad de aplicar todos los conceptos que se revisaron en esta unidad de aprendizaje. La primera entrega no fue tan retadora, pero al diseñar la función main pude comprender mejor cómo funcionan los ciclos while y los condicionales, me di cuenta de que con saber usar for, while, if, or y and puedes hacer muchas cosas en muy pocas líneas de código. La entrega 2 definitivamente me resultó más compleja que la anterior puesto que tuve que diseñar muchas funciones. Aprendí que las listas son muy peligrosas y que modificarlas es todo un reto, pero lo bueno es que en clase aprendí métodos que me facilitaron trabajar con las listas y matrices. El mayor reto fue utilizar los índices de las listas de manera corrrecta y eficiente, así como los valores booleanos. Además, para algunas funciones tuve que crear otras que me facilitaran el proceso, por lo que terminé escribiendo más de las 6 funciones que requería el programa. También pude refelxionar acerca de la importancia de cometer errores, ya que en el proceso de crear mi código me quivoqué una infinidad de veces, era una saga interminable de mensajes de error, y gracias a estos pude aprender a debugear y fortalecer mis hablidades como programadora.
#
# Resolver este reto iba más allá de saber usar corectamente un ciclo for o manejar listas o archivos, sino que primero había que plantear una forma de resolverlo, es decir, primero se tiene que tener una idea de cómo atacar al problema, un algoritmo, para así poder después traducirlo a un lenguaje de programación, en este caso, python. Por esto, gracias a este reto pude mejorar mi pensamiento computacional.
#
# Considero que le puse mucho empeño a este  proyecto, por lo que estoy orgullosa de los resultados. Sin embargo, estoy consciente de que podría haberlo hecho de una forma más profesional o eficiente. Tal vez debí haber practicado más y tomarme más tiempo para la realización de éste. Algo de lo que también estoy orgullosa es de no haberme dado por vencida y de que seguí intentando hasta que el programa fuera funcional.

# %%
nombre_archivo = "preguntas_guardadas.txt"
def leer_archivo(nombre):
  preguntas = []
  with open(nombre_archivo, "r") as archivo:
    contenido = archivo.readlines()
    for linea in contenido:
      strings = linea.split(",")
      strings[7] = strings[7][:-1]
      strings[0] = int(strings[0])
      strings[1] = int(strings[1])
      preguntas.append(strings)
  return preguntas


def grabar_archivo(nombre, lista_preguntas):
  with open(nombre, "w") as archivo:
    for pregunta in lista_preguntas:
      pregunta[0] = str(pregunta[0])
      pregunta[1] = str(pregunta[1])
      texto = ",".join(pregunta)
      archivo.write(texto + "\n")

enfoques = ["", "Lectura", "Matemáticas", "Ciencias"]
ids_mate = []
ids_lectura = []
ids_ciencias = []
preguntas_quiz = []
contador_usuario = 0
calificaciones = []


def registrar_pregunta():
  preguntas = leer_archivo(nombre_archivo)
  pregunta = []
  print("Bienvenido a la opción para registrar preguntas, por favor sigue las instrucciones")
  id_pregunta = len(preguntas) + 1
  print(f"ID de la pregunta: {id_pregunta}")
  pregunta.append(id_pregunta)
  while True:
    enfoque = int(input("Ingresa el número de enfoque de la pregunta:\n"
    "Para Lectura escriba 1, Para Matemáticas escriba 2, Para Ciencias escriba 3: "))
    if enfoque >= 1 and enfoque <= 3:
      pregunta.append(enfoque)
      break
    else:
      print("Número incorrecto.\n")
  texto_pregunta = input("Ingresa el texto de la pregunta: ")
  pregunta.append(texto_pregunta)
  for num in range(4):
    respuesta = input("Ingresa la respuesta " + str(num + 1) + ": ")
    pregunta.append(respuesta)
  correcta = input("Ingresa la respuesta correcta: ")
  pregunta.append(correcta)
  preguntas.append(pregunta)
  grabar_archivo(nombre_archivo, preguntas)


def actualizar_pregunta():
  preguntas = leer_archivo(nombre_archivo)
  existe = False
  print("Bienvenido a la opción para actualizar preguntas, por favor sigue las instrucciones \n"
  "A continuación se despliega la lista de preguntas guardadas\n")
  print(preguntas)
  for pregunta in preguntas:
    id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = pregunta  # esto (pregunta) es una lista, hacemos asignación múltiple
    print(f"ID de la pregunta: {id_pregunta} \nEnfoque de la pregunta: {enfoques[enfoque]} \nPregunta: {texto_pregunta}")
    print(f"a){respuesta1:<15}b){respuesta2:<15}c){respuesta3:<15}d){respuesta4:<15} \n")
  id_cambio = int(input("Ingresa el id de la pregunta que quieres cambiar: "))
  for pregunta in preguntas:
    id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = pregunta
    if id_cambio == id_pregunta:
      existe = True
      print(f"\nPregunta: {texto_pregunta}\na){respuesta1:<15}b){respuesta2:<15}c){respuesta3:<15}d){respuesta4:<15}\nCorrecta: {correcta}")
      enfoque_nuevo = input("Ingresa el número de enfoque de la pregunta:\n"
                      "Para Lectura escriba 1, Para Matemáticas escriba 2, Para Ciencias escriba 3: ")
      texto_pregunta_nueva = input("Ingresa el texto de la pregunta: ")
      respuesta_nueva1 = input("Ingresa la respuesta 1: ")
      respuesta_nueva2 = input("Ingresa la respuesta 2: ")
      respuesta_nueva3 = input("Ingresa la respuesta 3: ")
      respuesta_nueva4 = input("Ingresa la respuesta 4: ")
      correcta_nueva = input("Ingresa la respuesta correcta:")
      pregunta_seguro = input("¿Está seguro de que quiere actualizar los datos de la pregunta? (si/no): ")
      if pregunta_seguro.lower() == "si":
        if enfoque_nuevo == '':
          pass
        else:
          pregunta[1] = int(enfoque_nuevo)
        if texto_pregunta_nueva == '':
          pass
        else:
          pregunta[2] = texto_pregunta_nueva
        if respuesta_nueva1 == '':
          pass
        else:
          pregunta[3] = respuesta_nueva1
        if respuesta_nueva2 == '':
          pass
        else:
          pregunta[4] = respuesta_nueva2
        if respuesta_nueva3 == '':
          pass
        else:
          pregunta[5] = respuesta_nueva3
        if respuesta_nueva4 == '':
          pass
        else:
          pregunta[6] = respuesta_nueva4
        if correcta_nueva == '':
          pass
        else:
          pregunta[7] = correcta_nueva
      else:
        pass
      break
  if not existe:
    print("No existe ninguna pregunta con este ID.")
  grabar_archivo(nombre_archivo, preguntas)


def organizar_preguntas(lista_preguntas):
  for pregunta in lista_preguntas:
    id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = pregunta
    if enfoque == 1 and id_pregunta not in ids_lectura:
      ids_lectura.append(id_pregunta)
    elif enfoque == 2 and id_pregunta not in ids_mate:
      ids_mate.append(id_pregunta)
    elif enfoque == 3 and id_pregunta not in ids_ciencias:
      ids_ciencias.append(id_pregunta)


def estudiar_area():
  preguntas = leer_archivo(nombre_archivo)
  organizar_preguntas(preguntas)
  preguntas_estudiar = []
  print("Bienvenido a la opción para estudiar preguntas de cierta área, por favor sigue las instrucciones: \n")
  enfoque_estudiar = int(input("Ingrese el área de enfoque a estudiar\nPara Lectura escriba 1, Para Matemáticas escriba 2, Para Ciencias escriba 3: "))
  if enfoque_estudiar == 1:
    print(f"Cantidad de preguntas disponibles del enfoque Lectura: {len(ids_lectura)}")
  elif enfoque_estudiar == 2:
    print(f"Cantidad de preguntas disponibles del enfoque Matemáticas: {len(ids_mate)}")
  elif enfoque_estudiar == 3:
    print(f"Cantidad de preguntas disponibles del enfoque Ciencias: {len(ids_ciencias)}")
  cantidad_preguntas = int(input("Ingrese la cantidad de preguntas a estudiar: "))
  if enfoque_estudiar == 1 and len(ids_lectura) >= cantidad_preguntas:
    for num in range(cantidad_preguntas):
      preguntas_estudiar.append(ids_lectura[num])
    for id in preguntas_estudiar:
      id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = preguntas[id - 1]
      print(f"\nPregunta: {texto_pregunta}\na){respuesta1:<15}b){respuesta2:<15}c){respuesta3:<15}d){respuesta4:<15}\nCorrecta: {correcta}")
  elif enfoque_estudiar == 2 and len(ids_mate) >= cantidad_preguntas:
    for num in range(cantidad_preguntas):
      preguntas_estudiar.append(ids_mate[num])
    for id in preguntas_estudiar:
      id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = preguntas[id - 1]
      print(f"\nPregunta: {texto_pregunta}\na){respuesta1:<15}b){respuesta2:<15}c){respuesta3:<15}d){respuesta4:<15}\nCorrecta: {correcta}")
  elif enfoque_estudiar == 3 and len(ids_ciencias) >= cantidad_preguntas:
    for num in range(cantidad_preguntas):
      preguntas_estudiar.append(ids_ciencias[num])
    for id in preguntas_estudiar:
      id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = preguntas[id - 1]
      print(f"\nPregunta: {texto_pregunta}\na){respuesta1:<15}b){respuesta2:<15}c){respuesta3:<15}d){respuesta4:<15}\nCorrecta: {correcta}")
  else:
    print("No hay suficientes preguntas de esta área.")


def presentar_quiz():
  preguntas = leer_archivo(nombre_archivo)
  global contador_usuario
  preguntas_quiz.clear()
  organizar_preguntas(preguntas)
  existe_enfoque1 = False
  existe_enfoque2 = False
  existe_enfoque3 = False
  if len(preguntas) >= 10:
    if len(ids_lectura) >= 1 and len(ids_mate) >= 1 and len(ids_ciencias) >= 1:
      # rellenar la lista preguntas_quiz con las primeras 8 listas de preguntas
      for num in range(8):
        preguntas_quiz.append(preguntas[num])
      for pregunta in preguntas_quiz:
        id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = pregunta
        if enfoque == 1:
          existe_enfoque1 = True
        if enfoque == 2:
          existe_enfoque2 = True
        if enfoque == 3:
          existe_enfoque3 = True
      if existe_enfoque1 and existe_enfoque2 and existe_enfoque3:
        completar_1_2_3(preguntas)  # completar las 2 que faltan
      elif existe_enfoque1 and existe_enfoque2:
        completar_1_2(preguntas)  # completar las 2 que faltan con 3
      elif existe_enfoque1 and existe_enfoque3:
        completar_1_3(preguntas)  # completar las 2 que faltan con 2
      elif existe_enfoque2 and existe_enfoque3:
        completar_2_3(preguntas)   # completar las 2 que faltan con 1
      elif existe_enfoque1:
        completar_1(preguntas)  # completar las 2 que faltan con 2 y 3
      elif existe_enfoque2:
        completar_2(preguntas)     # completar las 2 que faltan con 1 y 3
      elif existe_enfoque3:
        completar_3(preguntas)   # completar las 2 que faltan con 2 y 1
      else:
        print("Todos los casos fueron cubierto y esto nunca se debe imprimir.")
    else:
      print("Debe haber al menos 1 pregunta de cada enfoque.")
  else:
    print("Deben haber al menos 10 preguntas.")
  contador_correctas = 0
  contador_incorrectas = 0
  import time
  print(f"\nEl quiz tiene una duración de 20 minutos.")
  start = time.time()
  for pregunta in preguntas_quiz:
    id_pregunta, enfoque, texto_pregunta, respuesta1, respuesta2, respuesta3, respuesta4, correcta = pregunta
    print(f"\nPregunta: {texto_pregunta}\n{respuesta1:<15}{respuesta2:<15}{respuesta3:<15}{respuesta4:<15} \n")
    respuesta_usuario = input("¿Cuál es la respuesta correcta? ")
    finish = time.time()
    segundos_en_contestar = finish - start
    segundos_restantes = 1200 - segundos_en_contestar
    print(f"\nTiempo restante: {int(segundos_restantes // 60)} minutos y {round(segundos_restantes % 60)} segundos.")
    if respuesta_usuario == correcta:
      contador_correctas += 1
    else:
      contador_incorrectas += 1
  contador_usuario += 1
  calificaciones.append(contador_correctas)


def completar_1_2_3(preguntas):
  preguntas_quiz.append(preguntas[-1])
  preguntas_quiz.append(preguntas[-2])


def completar_1_2(preguntas):
  if len(ids_ciencias) > 1:
    # agregar las dos preguntas de el enfoque de ciencias
    preguntas_quiz.append(preguntas[ids_ciencias[0] - 1])
    preguntas_quiz.append(preguntas[ids_ciencias[1] - 1])
  else:
    preguntas_quiz.append(preguntas[-1])
    preguntas_quiz.append(preguntas[ids_ciencias[0]-1])   # agregar el único elemento de preguntas ciencias



def completar_1_3(preguntas):
  if len(ids_mate) > 1:
    # agregar las dos preguntas de el enfoque de mate
    preguntas_quiz.append(preguntas[ids_mate[0] - 1])
    preguntas_quiz.append(preguntas[ids_mate[1] - 1])
  else:
    preguntas_quiz.append(preguntas[-1])
    preguntas_quiz.append(preguntas[ids_mate[0] - 1])   # agregar el único elemento de preguntas mate


def completar_2_3(preguntas):
  if len(ids_lectura) > 1:
    # agregar las dos preguntas de el enfoque de lectura
    preguntas_quiz.append(preguntas[ids_lectura[0] - 1])
    preguntas_quiz.append(preguntas[ids_lectura[1] - 1])
  else:
    preguntas_quiz.append(preguntas[-1])
    preguntas_quiz.append(preguntas[ids_lectura[0] - 1])   # agregar el único elemento de preguntas lectura


def completar_1(preguntas):
  preguntas_quiz.append(preguntas[ids_mate[0] - 1])
  preguntas_quiz.append(preguntas[ids_ciencias[0] - 1])


def completar_2(preguntas):
  preguntas_quiz.append(preguntas[ids_lectura[0] - 1])
  preguntas_quiz.append(preguntas[ids_ciencias[0] - 1])


def completar_3(preguntas):
  preguntas_quiz.append(preguntas[ids_lectura[0] - 1])
  preguntas_quiz.append(preguntas[ids_mate[0] - 1])


def reportar_calificaciones():
  if contador_usuario > 0:
    promedio = sum(calificaciones * 10) / len(calificaciones)
    total_preguntas = contador_usuario * 10
    total_preguntas_correctas = sum(calificaciones)
    porcentaje_correctas = (total_preguntas_correctas * 100) / total_preguntas
    porcetaje_incorrectas = 100 - porcentaje_correctas
    print(f"Total de usuarios:           {contador_usuario}\nPromedio de calificaciones:  {promedio}\n"
          f"Preguntas correctas:         {porcentaje_correctas}%\nPreguntas incorrectas:       {porcetaje_incorrectas}%")
  else:
    print("Aún no hay calificaciones por reportar.")

def menu():
  print("""Menú de opciones:
        1.	Alta de preguntas de prueba PISA (lectura, matemáticas, ciencias)
        2.	Actualizar preguntas de la prueba PISA (lectura, matemáticas, ciencias)
        3.	Estudiar preguntas de cierta área (lectura, matemáticas, ciencias)
        4.	Presentar un quiz (lectura, matemáticas, ciencias)
        5.	Reporte de calificaciones
        6.	Salir"""
  )
  opcion = int(input("Selecciona una opción: "))
  return opcion


def salir():
  print("Gracias por usar el sistema, hasta pronto!")


def main():
  opcion = 0

  while opcion != 6:
    opcion = menu()
    if opcion == 1:
      registrar_pregunta()
    elif opcion == 2:
      actualizar_pregunta()
    elif opcion == 3:
      estudiar_area()
    elif opcion == 4:
      presentar_quiz()
    elif opcion == 5:
      reportar_calificaciones()
    elif opcion > 6 or opcion < 1:
      print("Opción incorrecta")
  salir()

# %% [markdown]
# ## ***Ejecución***

# %%
main()
# Out:
# Menú de opciones:
#         1.	Alta de preguntas de prueba PISA (lectura, matemáticas, ciencias)
#         2.	Actualizar preguntas de la prueba PISA (lectura, matemáticas, ciencias)
#         3.	Estudiar preguntas de cierta área (lectura, matemáticas, ciencias)
#         4.	Presentar un quiz (lectura, matemáticas, ciencias)
#         5.	Reporte de calificaciones
#         6.	Salir
# Selecciona una opción: 1
# Bienvenido a la opción para registrar preguntas, por favor sigue las instrucciones
# ID de la pregunta: 13
# Ingresa el número de enfoque de la pregunta:
# Para Lectura escriba 1, Para Matemáticas escriba 2, Para Ciencias escriba 3: 2
# Ingresa el texto de la pregunta: 4+5*8
# Ingresa la respuesta 1: 72
# Ingresa la respuesta 2: 44
# Ingresa la respuesta 3: 45
# Ingresa la respuesta 4: 67
# Ingresa la respuesta correcta: 44
# Menú de opciones:
#         1.	Alta de preguntas de prueba PISA (lectura, matemáticas, ciencias)
# ...
